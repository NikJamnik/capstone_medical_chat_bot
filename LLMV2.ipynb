# %%
# !pip install langchain langchain-community langchain-openai langchain-pinecone
# !pip install pypdf
# !pip install pinecone
# !pip install datasets
# Upgrade to the latest version with gRPC extras
# !pip install "pinecone[grpc]" --upgrade
# Upgrade to the latest version with asyncio extras
# !pip install "pinecone[asyncio]" --upgrade
# !pip install openai
# !pip install datasets
# !pip install ragas
# !pip install python-telegram-bot==13.15
# !pip install renumics-spotlight
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.11/dist-packages (0.3.23)
# Collecting langchain-community
#   Downloading langchain_community-0.3.21-py3-none-any.whl.metadata (2.4 kB)
# Collecting langchain-openai
#   Downloading langchain_openai-0.3.14-py3-none-any.whl.metadata (2.3 kB)
# Collecting langchain-pinecone
#   Downloading langchain_pinecone-0.2.5-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.51 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.51)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.28)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.11.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (3.11.15)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (9.1.2)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.8.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy<3,>=1.26.2 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.0.2)
# Collecting langchain-core<1.0.0,>=0.3.51 (from langchain)
#   Downloading langchain_core-0.3.53-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: openai<2.0.0,>=1.68.2 in /usr/local/lib/python3.11/dist-packages (from langchain-openai) (1.72.0)
# Collecting tiktoken<1,>=0.7 (from langchain-openai)
#   Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting pinecone<7.0.0,>=6.0.0 (from pinecone[async]<7.0.0,>=6.0.0->langchain-pinecone)
#   Downloading pinecone-6.0.2-py3-none-any.whl.metadata (9.0 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community)
#   Downloading aiohttp-3.10.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting langchain-tests<1.0.0,>=0.3.7 (from langchain-pinecone)
#   Downloading langchain_tests-0.3.19-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.4.2)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.19.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.51->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.51->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.51->langchain) (4.13.1)
# Requirement already satisfied: pytest<9,>=7 in /usr/local/lib/python3.11/dist-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (8.3.5)
# Collecting pytest-asyncio<1,>=0.20 (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone)
#   Downloading pytest_asyncio-0.26.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.11/dist-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.28.1)
# Collecting syrupy<5,>=4 (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone)
#   Downloading syrupy-4.9.1-py3-none-any.whl.metadata (38 kB)
# Collecting pytest-socket<1,>=0.6.0 (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone)
#   Downloading pytest_socket-0.7.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (0.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (4.67.1)
# Requirement already satisfied: certifi>=2019.11.17 in /usr/local/lib/python3.11/dist-packages (from pinecone<7.0.0,>=6.0.0->pinecone[async]<7.0.0,>=6.0.0->langchain-pinecone) (2025.1.31)
# Collecting pinecone-plugin-interface<0.0.8,>=0.0.7 (from pinecone<7.0.0,>=6.0.0->pinecone[async]<7.0.0,>=6.0.0->langchain-pinecone)
#   Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from pinecone<7.0.0,>=6.0.0->pinecone[async]<7.0.0,>=6.0.0->langchain-pinecone) (2.8.2)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from pinecone<7.0.0,>=6.0.0->pinecone[async]<7.0.0,>=6.0.0->langchain-pinecone) (2.3.0)
# WARNING: pinecone 6.0.2 does not provide the extra 'async'
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.25.0->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.51->langchain) (3.0.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest<9,>=7->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest<9,>=7->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (1.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.5.3->pinecone<7.0.0,>=6.0.0->pinecone[async]<7.0.0,>=6.0.0->langchain-pinecone) (1.17.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: propcache>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Downloading langchain_community-0.3.21-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 64.9 MB/s eta 0:00:00
# Downloading langchain_openai-0.3.14-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 5.1 MB/s eta 0:00:00
# Downloading langchain_pinecone-0.2.5-py3-none-any.whl (16 kB)
# Downloading aiohttp-3.10.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 44.2 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading langchain_core-0.3.53-py3-none-any.whl (433 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 433.3/433.3 kB 27.1 MB/s eta 0:00:00
# Downloading langchain_tests-0.3.19-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 3.0 MB/s eta 0:00:00
# Downloading pinecone-6.0.2-py3-none-any.whl (421 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.9/421.9 kB 25.6 MB/s eta 0:00:00
# Downloading pydantic_settings-2.8.1-py3-none-any.whl (30 kB)
# Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 38.7 MB/s eta 0:00:00
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.0 MB/s eta 0:00:00
# Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl (6.2 kB)
# Downloading pytest_asyncio-0.26.0-py3-none-any.whl (19 kB)
# Downloading pytest_socket-0.7.0-py3-none-any.whl (6.8 kB)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading syrupy-4.9.1-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 kB 4.1 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: python-dotenv, pinecone-plugin-interface, mypy-extensions, marshmallow, httpx-sse, typing-inspect, tiktoken, syrupy, pytest-socket, pytest-asyncio, pinecone, aiohttp, pydantic-settings, dataclasses-json, langchain-core, langchain-tests, langchain-openai, langchain-pinecone, langchain-community
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.11.15
#     Uninstalling aiohttp-3.11.15:
#       Successfully uninstalled aiohttp-3.11.15
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.51
#     Uninstalling langchain-core-0.3.51:
#       Successfully uninstalled langchain-core-0.3.51
# Successfully installed aiohttp-3.10.11 dataclasses-json-0.6.7 httpx-sse-0.4.0 langchain-community-0.3.21 langchain-core-0.3.53 langchain-openai-0.3.14 langchain-pinecone-0.2.5 langchain-tests-0.3.19 marshmallow-3.26.1 mypy-extensions-1.0.0 pinecone-6.0.2 pinecone-plugin-interface-0.0.7 pydantic-settings-2.8.1 pytest-asyncio-0.26.0 pytest-socket-0.7.0 python-dotenv-1.1.0 syrupy-4.9.1 tiktoken-0.9.0 typing-inspect-0.9.0
# Collecting pypdf
#   Downloading pypdf-5.4.0-py3-none-any.whl.metadata (7.3 kB)
# Downloading pypdf-5.4.0-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.3/302.3 kB 18.8 MB/s eta 0:00:00
# Installing collected packages: pypdf
# Successfully installed pypdf-5.4.0
# Requirement already satisfied: pinecone in /usr/local/lib/python3.11/dist-packages (6.0.2)
# Requirement already satisfied: certifi>=2019.11.17 in /usr/local/lib/python3.11/dist-packages (from pinecone) (2025.1.31)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from pinecone) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from pinecone) (2.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.11/dist-packages (from pinecone) (4.13.1)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from pinecone) (2.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.5.3->pinecone) (1.17.0)
# Collecting datasets
#   Downloading datasets-3.5.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.12.0,>=2023.1.0 (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.10.11)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.2)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.19.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: propcache>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.3.1)
# Downloading datasets-3.5.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 28.1 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.6 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 17.0 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 11.5 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 17.4 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2024.12.0 which is incompatible.
# Successfully installed datasets-3.5.0 dill-0.3.8 fsspec-2024.12.0 multiprocess-0.70.16 xxhash-3.5.0
# Requirement already satisfied: pinecone[grpc] in /usr/local/lib/python3.11/dist-packages (6.0.2)
# Requirement already satisfied: certifi>=2019.11.17 in /usr/local/lib/python3.11/dist-packages (from pinecone[grpc]) (2025.1.31)
# Requirement already satisfied: googleapis-common-protos>=1.66.0 in /usr/local/lib/python3.11/dist-packages (from pinecone[grpc]) (1.69.2)
# Requirement already satisfied: grpcio>=1.59.0 in /usr/local/lib/python3.11/dist-packages (from pinecone[grpc]) (1.71.0)
# Collecting lz4>=3.1.3 (from pinecone[grpc])
#   Downloading lz4-4.4.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from pinecone[grpc]) (0.0.7)
# Requirement already satisfied: protobuf<6.0,>=5.29 in /usr/local/lib/python3.11/dist-packages (from pinecone[grpc]) (5.29.4)
# Collecting protoc-gen-openapiv2<0.0.2,>=0.0.1 (from pinecone[grpc])
#   Downloading protoc_gen_openapiv2-0.0.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from pinecone[grpc]) (2.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.11/dist-packages (from pinecone[grpc]) (4.13.1)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from pinecone[grpc]) (2.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.5.3->pinecone[grpc]) (1.17.0)
# Downloading lz4-4.4.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 44.3 MB/s eta 0:00:00
# Downloading protoc_gen_openapiv2-0.0.1-py3-none-any.whl (7.9 kB)
# Installing collected packages: lz4, protoc-gen-openapiv2
# Successfully installed lz4-4.4.4 protoc-gen-openapiv2-0.0.1
# Requirement already satisfied: pinecone[asyncio] in /usr/local/lib/python3.11/dist-packages (6.0.2)
# Requirement already satisfied: aiohttp>=3.9.0 in /usr/local/lib/python3.11/dist-packages (from pinecone[asyncio]) (3.10.11)
# Requirement already satisfied: certifi>=2019.11.17 in /usr/local/lib/python3.11/dist-packages (from pinecone[asyncio]) (2025.1.31)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from pinecone[asyncio]) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from pinecone[asyncio]) (2.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.11/dist-packages (from pinecone[asyncio]) (4.13.1)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from pinecone[asyncio]) (2.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.9.0->pinecone[asyncio]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.9.0->pinecone[asyncio]) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.9.0->pinecone[asyncio]) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.9.0->pinecone[asyncio]) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.9.0->pinecone[asyncio]) (6.4.2)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.9.0->pinecone[asyncio]) (1.19.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.5.3->pinecone[asyncio]) (1.17.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.12.0->aiohttp>=3.9.0->pinecone[asyncio]) (3.10)
# Requirement already satisfied: propcache>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.12.0->aiohttp>=3.9.0->pinecone[asyncio]) (0.3.1)
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.72.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.11.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.13.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.12.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.10.11)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.2)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.19.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: propcache>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.3.1)
# Collecting ragas
#   Downloading ragas-0.2.14-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from ragas) (2.0.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (from ragas) (3.5.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.11/dist-packages (from ragas) (0.9.0)
# Requirement already satisfied: langchain in /usr/local/lib/python3.11/dist-packages (from ragas) (0.3.23)
# Requirement already satisfied: langchain-core in /usr/local/lib/python3.11/dist-packages (from ragas) (0.3.53)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.11/dist-packages (from ragas) (0.3.21)
# Requirement already satisfied: langchain_openai in /usr/local/lib/python3.11/dist-packages (from ragas) (0.3.14)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ragas) (1.6.0)
# Collecting appdirs (from ragas)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: pydantic>=2 in /usr/local/lib/python3.11/dist-packages (from ragas) (2.11.3)
# Requirement already satisfied: openai>1 in /usr/local/lib/python3.11/dist-packages (from ragas) (1.72.0)
# Collecting diskcache>=5.6.3 (from ragas)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai>1->ragas) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>1->ragas) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai>1->ragas) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai>1->ragas) (0.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>1->ragas) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai>1->ragas) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai>1->ragas) (4.13.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ragas) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ragas) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ragas) (0.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets->ragas) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets->ragas) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets->ragas) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets->ragas) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets->ragas) (2.32.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets->ragas) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets->ragas) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets->ragas) (2024.12.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets->ragas) (3.10.11)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets->ragas) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets->ragas) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets->ragas) (6.0.2)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from langchain->ragas) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /usr/local/lib/python3.11/dist-packages (from langchain->ragas) (0.3.28)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain->ragas) (2.0.40)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core->ragas) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core->ragas) (1.33)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.11/dist-packages (from langchain-community->ragas) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community->ragas) (2.8.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community->ragas) (0.4.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken->ragas) (2024.11.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->ragas) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->ragas) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->ragas) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->ragas) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->ragas) (6.4.2)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->ragas) (1.19.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai>1->ragas) (3.10)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->ragas) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->ragas) (0.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai>1->ragas) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai>1->ragas) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>1->ragas) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core->ragas) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain->ragas) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain->ragas) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain->ragas) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community->ragas) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets->ragas) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets->ragas) (2.3.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain->ragas) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->ragas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->ragas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->ragas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->ragas) (1.17.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community->ragas) (1.0.0)
# Requirement already satisfied: propcache>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets->ragas) (0.3.1)
# Downloading ragas-0.2.14-py3-none-any.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.2/187.2 kB 13.1 MB/s eta 0:00:00
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.5 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Installing collected packages: appdirs, diskcache, ragas
# Successfully installed appdirs-1.4.4 diskcache-5.6.3 ragas-0.2.14
# Collecting python-telegram-bot==13.15
#   Downloading python_telegram_bot-13.15-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from python-telegram-bot==13.15) (2025.1.31)
# Collecting tornado==6.1 (from python-telegram-bot==13.15)
#   Downloading tornado-6.1.tar.gz (497 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.4/497.4 kB 25.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting APScheduler==3.6.3 (from python-telegram-bot==13.15)
#   Downloading APScheduler-3.6.3-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: pytz>=2018.6 in /usr/local/lib/python3.11/dist-packages (from python-telegram-bot==13.15) (2025.2)
# Collecting cachetools==4.2.2 (from python-telegram-bot==13.15)
#   Downloading cachetools-4.2.2-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: setuptools>=0.7 in /usr/local/lib/python3.11/dist-packages (from APScheduler==3.6.3->python-telegram-bot==13.15) (75.2.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from APScheduler==3.6.3->python-telegram-bot==13.15) (1.17.0)
# Requirement already satisfied: tzlocal>=1.2 in /usr/local/lib/python3.11/dist-packages (from APScheduler==3.6.3->python-telegram-bot==13.15) (5.3.1)
# Downloading python_telegram_bot-13.15-py3-none-any.whl (519 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 35.3 MB/s eta 0:00:00
# Downloading APScheduler-3.6.3-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 4.9 MB/s eta 0:00:00
# Downloading cachetools-4.2.2-py3-none-any.whl (11 kB)
# Building wheels for collected packages: tornado
#   Building wheel for tornado (setup.py) ... done
#   Created wheel for tornado: filename=tornado-6.1-cp311-cp311-linux_x86_64.whl size=422007 sha256=f723ddc9747fdcbc2ccfb0998b28372cdeea5fd059254a650cd843d6109d6141
#   Stored in directory: /root/.cache/pip/wheels/f2/59/06/a9c85c7b17ec0fc9b1e2ae0c59e3d39255d5c0a38492e33fea
# Successfully built tornado
# Installing collected packages: tornado, cachetools, APScheduler, python-telegram-bot
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.4.2
#     Uninstalling tornado-6.4.2:
#       Successfully uninstalled tornado-6.4.2
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 5.5.2
#     Uninstalling cachetools-5.5.2:
#       Successfully uninstalled cachetools-5.5.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.1 which is incompatible.
# distributed 2024.12.1 requires tornado>=6.2.0, but you have tornado 6.1 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2024.12.0 which is incompatible.
# bokeh 3.6.3 requires tornado>=6.2, but you have tornado 6.1 which is incompatible.
# Successfully installed APScheduler-3.6.3 cachetools-4.2.2 python-telegram-bot-13.15 tornado-6.1
# Collecting renumics-spotlight
#   Downloading renumics_spotlight-1.6.13-py3-none-any.whl.metadata (5.7 kB)
# Collecting aiofiles (from renumics-spotlight)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.11/dist-packages (from renumics-spotlight) (1.4.4)
# Collecting av (from renumics-spotlight)
#   Downloading av-14.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.7 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from renumics-spotlight) (8.1.8)
# Collecting databases>=0.1.3 (from databases[sqlite]>=0.1.3->renumics-spotlight)
#   Downloading databases-0.9.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting datasets<3.0.0,>=2.12.0 (from datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight)
#   Downloading datasets-2.21.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: diskcache in /usr/local/lib/python3.11/dist-packages (from renumics-spotlight) (5.6.3)
# Collecting fastapi>=0.65.2 (from renumics-spotlight)
#   Downloading fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# Collecting filetype (from renumics-spotlight)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: h5py>3.0 in /usr/local/lib/python3.11/dist-packages (from renumics-spotlight) (3.13.0)
# Collecting httptools (from renumics-spotlight)
#   Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting httpx<0.24.0,>=0.23.0 (from renumics-spotlight)
#   Downloading httpx-0.23.3-py3-none-any.whl.metadata (7.1 kB)
# Collecting imagecodecs (from renumics-spotlight)
#   Downloading imagecodecs-2025.3.30-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: imageio>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from renumics-spotlight) (2.37.0)
# Collecting importlib_resources<5.8.0 (from renumics-spotlight)
#   Downloading importlib_resources-5.7.1-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.11/dist-packages (from renumics-spotlight) (7.7.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from renumics-spotlight) (3.1.6)
# Collecting loguru (from renumics-spotlight)
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from renumics-spotlight) (3.4.2)
# Requirement already satisfied: numba>=0.59 in /usr/local/lib/python3.11/dist-packages (from renumics-spotlight) (0.60.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from renumics-spotlight) (2.0.2)
# Requirement already satisfied: orjson in /usr/local/lib/python3.11/dist-packages (from renumics-spotlight) (3.10.16)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from renumics-spotlight) (24.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from renumics-spotlight) (2.2.2)
# Collecting pillow<11.0.0,>=10.0.0 (from renumics-spotlight)
#   Downloading pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.11/dist-packages (from renumics-spotlight) (3.16.0)
# Collecting py-machineid (from renumics-spotlight)
#   Downloading py_machineid-0.7.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.11/dist-packages (from renumics-spotlight) (18.1.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from renumics-spotlight) (2.11.3)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from renumics-spotlight) (2.8.1)
# Collecting pygltflib>=1.15.1 (from renumics-spotlight)
#   Downloading pygltflib-1.16.3.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.11/dist-packages (from renumics-spotlight) (2.32.3)
# Requirement already satisfied: rsa in /usr/local/lib/python3.11/dist-packages (from renumics-spotlight) (4.9)
# ...
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->renumics-spotlight) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->renumics-spotlight) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->renumics-spotlight) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->renumics-spotlight) (4.9.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->renumics-spotlight) (1.17.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.1->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (1.17.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=2.0.7->databases>=0.1.3->databases[sqlite]>=0.1.3->renumics-spotlight) (3.1.1)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (6.5.7)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated->pygltflib>=1.15.1->renumics-spotlight) (1.17.2)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (3.0.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (1.8.2)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (1.1.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.1->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->renumics-spotlight) (0.8.4)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->renumics-spotlight) (5.7.2)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (23.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (1.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->renumics-spotlight) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (4.3.7)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json>=0.0.25->pygltflib>=1.15.1->renumics-spotlight) (1.0.0)
# Requirement already satisfied: propcache>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets<3.0.0,>=2.12.0->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (0.3.1)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (4.23.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (1.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.24.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (2.6)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (1.8.0)
# Downloading renumics_spotlight-1.6.13-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 63.4 MB/s eta 0:00:00
# Downloading databases-0.9.0-py3-none-any.whl (25 kB)
# Downloading datasets-2.21.0-py3-none-any.whl (527 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 31.6 MB/s eta 0:00:00
# Downloading fastapi-0.115.12-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 8.1 MB/s eta 0:00:00
# Downloading httpx-0.23.3-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 5.9 MB/s eta 0:00:00
# Downloading importlib_resources-5.7.1-py3-none-any.whl (28 kB)
# Downloading pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 80.6 MB/s eta 0:00:00
# Downloading uvicorn-0.34.1-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 5.2 MB/s eta 0:00:00
# Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 67.4 MB/s eta 0:00:00
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading av-14.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 17.6 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (459 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 26.3 MB/s eta 0:00:00
# Downloading imagecodecs-2025.3.30-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (45.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 MB 14.5 MB/s eta 0:00:00
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 5.1 MB/s eta 0:00:00
# Downloading py_machineid-0.7.0-py3-none-any.whl (4.9 kB)
# Downloading trimesh-4.6.8-py3-none-any.whl (709 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 709.3/709.3 kB 34.2 MB/s eta 0:00:00
# Downloading validators-0.34.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 3.5 MB/s eta 0:00:00
# Downloading fsspec-2024.6.1-py3-none-any.whl (177 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 12.9 MB/s eta 0:00:00
# Downloading httpcore-0.16.3-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 kB 5.8 MB/s eta 0:00:00
# Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Downloading starlette-0.46.2-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 5.7 MB/s eta 0:00:00
# Downloading aiosqlite-0.21.0-py3-none-any.whl (15 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 56.1 MB/s eta 0:00:00
# Building wheels for collected packages: pygltflib
#   Building wheel for pygltflib (setup.py) ... done
#   Created wheel for pygltflib: filename=pygltflib-1.16.3-py3-none-any.whl size=27407 sha256=dd51f267e2b41d9f8079537eed041817a2391785f7cec85c68842fa56f5e3fff
#   Stored in directory: /root/.cache/pip/wheels/1e/75/a7/661db79759f1de86850bbbc3112020f4d18436bad637ea5673
# Successfully built pygltflib
# Installing collected packages: rfc3986, py-machineid, filetype, validators, uvloop, uvicorn, trimesh, pillow, loguru, jedi, importlib_resources, imagecodecs, httptools, fsspec, av, aiosqlite, aiofiles, starlette, httpcore, databases, pygltflib, httpx, fastapi, datasets, renumics-spotlight
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.1.0
#     Uninstalling pillow-11.1.0:
#       Successfully uninstalled pillow-11.1.0
#   Attempting uninstall: importlib_resources
#     Found existing installation: importlib_resources 6.5.2
#     Uninstalling importlib_resources-6.5.2:
#       Successfully uninstalled importlib_resources-6.5.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.12.0
#     Uninstalling fsspec-2024.12.0:
#       Successfully uninstalled fsspec-2024.12.0
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.7
#     Uninstalling httpcore-1.0.7:
#       Successfully uninstalled httpcore-1.0.7
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
#   Attempting uninstall: datasets
#     Found existing installation: datasets 3.5.0
#     Uninstalling datasets-3.5.0:
#       Successfully uninstalled datasets-3.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-tests 0.3.19 requires httpx<1,>=0.25.0, but you have httpx 0.23.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# google-genai 1.10.0 requires httpx<1.0.0,>=0.28.1, but you have httpx 0.23.3 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2024.6.1 which is incompatible.
# bokeh 3.6.3 requires tornado>=6.2, but you have tornado 6.1 which is incompatible.
# nibabel 5.3.2 requires importlib-resources>=5.12; python_version < "3.12", but you have importlib-resources 5.7.1 which is incompatible.
# Successfully installed aiofiles-24.1.0 aiosqlite-0.21.0 av-14.3.0 databases-0.9.0 datasets-2.21.0 fastapi-0.115.12 filetype-1.2.0 fsspec-2024.6.1 httpcore-0.16.3 httptools-0.6.4 httpx-0.23.3 imagecodecs-2025.3.30 importlib_resources-5.7.1 jedi-0.19.2 loguru-0.7.3 pillow-10.4.0 py-machineid-0.7.0 pygltflib-1.16.3 renumics-spotlight-1.6.13 rfc3986-1.5.0 starlette-0.46.2 trimesh-4.6.8 uvicorn-0.34.1 uvloop-0.21.0 validators-0.34.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Import Libary**

# %%
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
import os
from pinecone import Pinecone, ServerlessSpec
from langchain_openai import ChatOpenAI
from langchain.chains import RetrievalQA
import requests
from bs4 import BeautifulSoup
import time
import random
from openai import OpenAI
import pandas as pd
from sentence_transformers import SentenceTransformer
import numpy as np
from ragas.metrics import (
    answer_relevancy,
    context_precision,
    context_recall,
    faithfulness,
)
from ragas import evaluate
from datasets import Dataset
import umap
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity
import plotly.express as px
import time
import csv
from datetime import datetime
from dotenv import load_dotenv

# %%
from google.colab import userdata
# Access your secrets
openai_key = userdata.get("OPENAI_API_KEY")
pinecone_key = userdata.get("PINECONE_API_KEY")
telegram_token = userdata.get("TELEGRAM_TOKEN")

# %% [markdown]
# **1.Load PDF File and make chunks**

# %%
# Load the PDF
loader = PyPDFLoader("/content/drive/MyDrive/Capstone/Data/ClinicalDermatology.pdf")
pages = loader.load()

# Split into chunks
splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100)
chunks = splitter.split_documents(pages)

# %% [markdown]
# **2. Embedding**

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings

embedding = HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2")
# Out:
# <ipython-input-4-43465a1e40dd>:3: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding = HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2")
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %% [markdown]
# **3. Setting environmental variables**

# %%
os.environ['PINECONE_API_KEY'] = pinecone_key
os.environ["OPENAI_API_KEY"] = openai_key
os.environ["TELEGRAM_TOKEN"] = telegram_token

# %% [markdown]
# **4.Create vector Database**

# %% [markdown]
# pc = Pinecone(api_key="pinecone_key")
#
# index_name = "dermatologist-v2"
#
# pc.create_index(
#   name=index_name,
#   dimension=768,
#   metric="cosine",
#   spec=ServerlessSpec(
#     cloud="aws",
#     region="us-east-1"
#   )
# )

# %% [markdown]
# **5.Store chunks file in to vector database**

# %%
from langchain_pinecone import PineconeVectorStore
from google.colab import userdata
# Step 1: Connect to your existing index
pc = Pinecone(api_key=pinecone_key)
vectorstore = PineconeVectorStore(
    index_name="dermatologist-v2",
    embedding=embedding,
    namespace="clinical-derm"
)

# Step 2: Upload in batches (100–200 chunks per batch)
from tqdm import tqdm
batch_size = 100

for i in tqdm(range(0, len(chunks), batch_size)):
    chunk_batch = chunks[i:i+batch_size]
    vectorstore.add_documents(documents=chunk_batch)
# Out:
# 100%|██████████| 25/25 [23:48<00:00, 57.13s/it]

# %% [markdown]
# **6.Setting up a Retrieval-Augmented Generation (RAG) pipeline using a language model (LLM) and a retriever.**

# %%
llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0,
                 openai_api_key=openai_key)

qa = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=vectorstore.as_retriever(),
    return_source_documents=True
)

# %% [markdown]
# **7.Test query**

# %%
query = "What are the main causes of psoriasis?"
result = qa.invoke({"query": query})

print("Answer:\n", result['result'])
# Out:
# Answer:
#  The main causes of psoriasis are still unknown, but there is often a genetic predisposition and sometimes an environmental trigger. The key abnormalities in psoriatic plaques involve hyperproliferation of keratinocytes and an inflammatory cell infiltrate with neutrophils and TH-1 type T lymphocytes.

# %%
query = "What are the main causes of acne and how to cure ?"
result = qa.invoke({"query": query})
print("Answer:\n", result['result'])
# Out:
# Answer:
#  The main causes of acne are not clearly mentioned in the provided context. However, it is stated that any dietary constituent, except iodine, can cause acne. As for the treatment, the text suggests that physical treatments like Ultraviolet B radiation therapy can help with acne exacerbations. Additionally, local treatments are usually enough for most patients with comedo-papular acne, while both local and systemic treatments may be needed for pustulocystic scarring acne. It is also mentioned that an optimistic approach, regular encouragement, and addressing any underlying causes are important in managing acne.

# %%
manual_ground_truths = {
    "What is dermatology?": "Dermatology is the study of skin and its associated structures, including the hair and the nails and their diseases.",
    "Name the five Ds of dermatological disease.": "The five Ds are Disfigurement, Disablement, Discomfort, Death, and Depression",
    "How many layers does skin have?": "Skin has two layers, the outer epidermis and the underlying dermis.",
    "Explain the difference between a nodule and a tumor.": "A nodule is a solid mass in the skin greater than 0.5cm in diameter. A tumor is less clearly defined, but is typically more than 1cm in diameter. Tumors can also be called 'large nodules'.",
    "How is a potential fungal infection tested?": "Scales or plucked hairs can be dissolved into an aqueous solution of 20% potassium hydroxide containing 40% dimethyl sulphoxide. The scale from the edge of a scaling lesion is vigorously scraped on to a glass slide with a No. 15 scalpel blade or the edge of a second glass slide. A drop or two of the KOH solution is run under the cover slip. After 5-10 min the mount is examined under a microscope with the condenser lens lowered to increase contrast.",
    "What kind of diagnosis is Tanzck smear used in?": "Tanzck smear, or cytology, can aid in diagnosis of viral infections such as herpes simplex and zoster, and of bullous diseases such as pemphigus.",
    "When should you use incisional vs. excisional biopsies?": "Excisional biopsy is preferable for most small lesions up to 0.5 cm diameter but incisional biopsy is chosen when the partial removal of a larger lesion is adequate for diagnosis, and complete removal might leave an unnecessary and unsightly scar.",
    "How does psoriasis affect the scalp?": "Areas of scaling are interspersed with normal skin; their lumpiness is more easily felt than seen.  Frequently, the psoriasis overflows just beyond the scalp margin. Significant hair loss is rare.",
    "What causes Lyell's Disease?": "Toxic epidermal necrolysis is usually a drug reaction, most commonly to sulphonamides, barbituates, carbamazepine, or allopurinol, but can also be a manifestation of graft-vs.-host disease.",
    "What other conditions can systemic lupus erythematosus be confused with?": "SLE is a great imitator. Its malar rash can be confused with sunburn, polymorphic light eruption, and rosacea. The discoid lesions are distinctive, but are also seen in discoid LE and in subacute cutaneous LE. Occasionally they look like psoriasis or lichen planus. The hair fall suggests telogen effluvium.",
    "Describe the symptoms of Acrocyanosis.": "The hands, feet, nose, ears, and cheeks become blue-red and cold. The palms are often cold and clammy.",
    "How can Raynaud's disease be treated?": "The main treatment is to protect the vulnerable digits from cold. Warm clothing reduces the need for peripheral vasoconstriction to conserve heat. Smoking should be abandoned. Calcium channel blockers e.g. nifedipine 10-30 mg three time daily are the most effective in parients with primary Raynaud's disease.",
    "How is Doxycycline different from Minocycline?": "It is a cheaper alternative to minocycline, but more frequently associated with phototoxic skin reactions.",
    "Are Tetracyclines safe for children?": "No, Tetracyclines should not be taken by children under 12 years as they are deposited in growing bone and developing teeth, causing stained teeth and dental hypoplasia.",
    "Where in the body are sweat glands?": "There are 2-3 million sweat glands distributed all over the body surface, but they are most numerous on the palms, soles, and axillae.",
    "Describe the phases of the hair cycle.": "There are three phases of follicular activity. 1 Anagen. The active phase of hair production. 2 Catagen. A short phase of conversion from active growth to the resting phase. Growth stops, and the end of the hair becomes club-shaped. 3 Telogen. A resting phase at the end of which the club hair is shed.",
    "What condition results from a cat bite?": "The infective agent is the baccilus Rochalimaea henselae. A few days after a cat bite or scratch, a reddish granulomatous papule appears at the site of inoculation.",
    "How is syphilis diagnosed?": "The diagnosis of syphilis in its infectious stages can be confirmed using dark field microscopy to show up spirochaetes in smears from chancres, oral lesions, or moist areas in a secondary eruption. Serological tests for syphilis become positive only some 5–6 weeks after infection usually a week or two after the appearance of the chancre. The traditional tests WR and VDRL have now been replaced by more specific ones e.g. the rapid plasma reagin test and the fluorescent treponemal antibody/absorption test. These more sensitive tests do not become negative after treatment if an infection has been present for more than a few months.",
    "Is dapsone an effective treatment for leprosy?": "The emergence of resistant strains of M. leprae means that it is no longer wise to treat leprosy with dapsone alone. It should now be used in combination, usually with clofazimine for lepromatous leprosy.",
    "What causes hair to turn grey early?": "Early greying of the hair is seen in the rare premature aging syndromes, such as Werner's syndrome, and in autoimmune conditions such as pernicious anaemia, thyroid disorders, and Addison's disease.",
    "Explain dermatological non-disease.": "This is a form of dysmorphophobia. The clinician can find no abnormality, but the distress felt by the patient leads to anxiety, depression, or even sucicide. Such patients are not uncommon. They expect dermatological solutions for complaints such as hair loss, or burning, itching, and redness of the face or genitals. The dermatologist, who can see nothing wrong, cannot solve matters and no treatment seems to help.",
    "Which drugs can cause toxic reactive erythema?": "Culprits include antibiotics, sulphonamides and related compounds, barbituates, phenylbutazone, and para-aminosalicylate.",
    "What conditions does cryotherapy treat?": "It is effective for viral warts, seborrhoeic keratoses, actinic keratoses, and some superficial skin tumors e.g. intraepidermal carcinoma and lentigo maligna."
}

# %%
from ragas.metrics import (
    answer_relevancy,
    context_precision,
    context_recall,
    faithfulness,
)
from ragas import evaluate
from datasets import Dataset

ragas_data = []

# Step 1: Extract answers using RAG model
for question, ground_truth in manual_ground_truths.items():
    result = qa.invoke({"query": f"{question}"})
    answer = result["result"]

    contexts = [doc.page_content for doc in result.get("source_documents", [])]

    ragas_data.append({
        "question": question,
        "answer": answer,
        "contexts": contexts,
        "ground_truth": ground_truth
    })

# Step 2: Convert to HuggingFace Dataset
dataset = Dataset.from_list(ragas_data)

# Step 3: Evaluate with RAGAS
results = evaluate(
    dataset,
    metrics=[
        answer_relevancy,
        context_precision,
        context_recall,
        faithfulness,
    ]
)

# Step 4: Print results
print(results)
# Out:
# Evaluating:   0%|          | 0/92 [00:00<?, ?it/s]
# {'answer_relevancy': 0.8285, 'context_precision': 0.6703, 'context_recall': 0.5072, 'faithfulness': 0.6629}

# %%
# model 2 Context Precision:  0.4149936306095072 Faithfulness:  0.5114133579400361

# %% [markdown]
# **8.Visulization**

# %%
metrics = ['Answer Relevancy', 'Context Precision', 'Context Recall', 'Faithfulness']
# Scores from your image
model_1_scores = [0.9128, 0.7464, 0.5290, 0.6600]
model_2_scores = [None, 0.4150, None, 0.5114]  # fill missing with None or np.nan

# Only keep metrics available in both models
metrics_to_plot = []
m1_vals = []
m2_vals = []

for i, score in enumerate(model_2_scores):
    if score is not None:
        metrics_to_plot.append(metrics[i])
        m1_vals.append(model_1_scores[i])
        m2_vals.append(model_2_scores[i])

# Create position index
y = np.arange(len(metrics_to_plot))
bar_height = 0.35

# Plot
plt.figure(figsize=(10, 6))
plt.barh(y + bar_height/2, m1_vals, bar_height, label='gpt-3.5-turbo', color='skyblue')
plt.barh(y - bar_height/2, m2_vals, bar_height, label='google/flan-t5-large', color='lightgreen')

# Style
plt.xlabel('Score')
plt.title('Model Comparison on RAG Evaluation Metrics')
plt.yticks(y, metrics_to_plot)
plt.xlim(0, 1)
plt.legend()
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Use the same contexts you've gathered from RAGAS prep
contexts = [doc for sample in ragas_data for doc in sample["contexts"]]

# Optional: deduplicate or truncate for clarity
unique_contexts = list(set(contexts))

# Embed using SentenceTransformer
model = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = model.encode(unique_contexts, show_progress_bar=True)

# Reduce to 2D using UMAP
reducer = umap.UMAP(n_neighbors=10, min_dist=0.1, metric="cosine")
embedding_2d = reducer.fit_transform(embeddings)

# Create a DataFrame for plotting
df_umap = pd.DataFrame(embedding_2d, columns=["x", "y"])
df_umap["context"] = unique_contexts

# Plot with matplotlib
plt.figure(figsize=(10, 8))
plt.scatter(df_umap["x"], df_umap["y"], s=20, alpha=0.7)
for i, txt in enumerate(df_umap["context"][:30]):  # Show first 30 labels max
    plt.annotate(txt[:40] + "...", (df_umap["x"][i], df_umap["y"][i]), fontsize=8, alpha=0.6)

plt.title("UMAP Projection of Retrieved Context Embeddings")
plt.xlabel("UMAP-1")
plt.ylabel("UMAP-2")
plt.grid(True)
plt.show()
# Out:
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
# Create or open the CSV file
csv_file = "retrieval_latency_log.csv"

# Create header if file does not exist
try:
    with open(csv_file, "x", newline='') as f:
        writer = csv.writer(f)
        writer.writerow(["timestamp", "query", "retrieval_latency"])
except FileExistsError:
    pass  # File already exists, skip header

# List of test queries
queries = [
    "What are the main causes of psoriasis?",
    "What are the main causes of acne and how to cure?",
    "What is the treatment for eczema?",
    "Explain the difference between a nodule and a tumor.",
    "What causes hair to turn grey early?",
    "How is a potential fungal infection tested?",
    "Is dapsone an effective treatment for leprosy?",
     "Which drugs can cause toxic reactive erythema?",
     "How many layers does skin have?"

]

# Run queries and log latency
for query in queries:
    start_time = time.time()
    result = qa.invoke({"query": query})
    latency = time.time() - start_time

    # Log to CSV
    with open(csv_file, "a", newline='') as f:
        writer = csv.writer(f)
        writer.writerow([datetime.now(), query, round(latency, 3)])

    print(f"Query: {query}")
    print("Answer:", result['result'])
    print(f"Retrieval Latency: {latency:.3f} seconds\n")
# Out:
# Query: What are the main causes of psoriasis?
# Answer: The main causes of psoriasis are still unknown, but there is often a genetic predisposition and sometimes an environmental trigger. The key abnormalities in psoriatic plaques involve hyperproliferation of keratinocytes and an inflammatory cell infiltrate with neutrophils and TH-1 type T lymphocytes.
# Retrieval Latency: 1.154 seconds
#
# Query: What are the main causes of acne and how to cure?
# Answer: The main causes of acne are not specified in the provided context. However, it is mentioned that any dietary constituent, except iodine, can cause acne. As for the treatment, the text suggests that local treatment is usually enough for most patients with comedo-papular acne, while both local and systemic treatment may be needed for pustulocystic scarring acne. Ultraviolet B radiation therapy can also help with exacerbations. It is important to have an optimistic approach, provide regular encouragement, and occasionally address any underlying causes that may be contributing to the acne.
# Retrieval Latency: 1.902 seconds
#
# Query: What is the treatment for eczema?
# Answer: The treatment for eczema typically involves using steroid lotions or creams, with the strength of the steroid determined by the severity of the eczema. In cases where there is an infective element present, medications like Vioform, bacitracin, fusidic acid, mupirocin, or neomycin can be incorporated into the treatment. Chronic eczema usually responds best to steroids in an ointment base.
# Retrieval Latency: 1.875 seconds
#
# Query: Explain the difference between a nodule and a tumor.
# Answer: A nodule is a solid mass in the skin, usually greater than 0.5 cm in diameter, which can be seen to be elevated or palpated. On the other hand, a tumor is a term that is more accurately defined based on microscopic pathology rather than clinical morphology. It describes an enlargement of tissues by normal or pathological material or cells that form a mass, usually more than 1 cm in diameter.
# Retrieval Latency: 1.395 seconds
#
# Query: What causes hair to turn grey early?
# Answer: Hair turning grey early can be caused by various factors such as rare premature aging syndromes like Werner's syndrome, autoimmune conditions like pernicious anemia, thyroid disorders, Addison's disease, and other genetic or health-related issues that affect the activity of melanocytes in the hair bulbs.
# Retrieval Latency: 1.115 seconds
#
# Query: How is a potential fungal infection tested?
# Answer: A potential fungal infection can be tested by dissolving scales or plucked hairs in an aqueous solution of 20% potassium hydroxide (KOH) containing 40% dimethyl sulphoxide (DMSO). The sample is then scraped onto a glass slide for examination under a microscope. Other samples that can be tested include nail clippings, the roofs of blisters, hair pluckings, and the contents of pustules when a candidal infection is suspected.
# Retrieval Latency: 2.086 seconds
#
# Query: Is dapsone an effective treatment for leprosy?
# Answer: Dapsone used to be an effective treatment for leprosy, but due to the emergence of resistant strains of M. leprae, it is no longer wise to treat leprosy with dapsone alone. It is now recommended to use dapsone in combination with other medications like rifampicin and clofazimine for leprosy treatment.
# Retrieval Latency: 1.277 seconds
#
# Query: Which drugs can cause toxic reactive erythema?
# Answer: Antibiotics (especially ampicillin), sulphonamides and related compounds (diuretics and hypoglycaemics), and barbiturates are known to cause toxic reactive erythema.
# Retrieval Latency: 0.990 seconds
#
# Query: How many layers does skin have?
# Answer: The skin has two layers: the outer layer is the epidermis, and the underlying layer is the dermis.
# Retrieval Latency: 0.684 seconds

# %%
df = pd.read_csv(csv_file)
df
# Out:
#                      timestamp  \
# 0   2025-04-16 18:41:25.048366
# 1   2025-04-16 18:41:26.976985
# 2   2025-04-16 18:41:28.258596
# 3   2025-04-16 18:41:29.558886
# 4   2025-04-16 18:41:30.572106
# 5   2025-04-16 18:41:31.981870
# 6   2025-04-16 18:41:35.720635
# 7   2025-04-16 18:41:36.575601
# 8   2025-04-16 18:41:37.284521
# 9   2025-04-16 20:01:39.637114
# 10  2025-04-16 20:01:41.539857
# 11  2025-04-16 20:01:43.415581
# 12  2025-04-16 20:01:44.811176
# 13  2025-04-16 20:01:45.926313
# 14  2025-04-16 20:01:48.012448
# 15  2025-04-16 20:01:49.289817
# 16  2025-04-16 20:01:50.280226
# 17  2025-04-16 20:01:50.964481
#
#                                                 query  retrieval_latency
# 0              What are the main causes of psoriasis?              1.425
# 1   What are the main causes of acne and how to cure?              1.928
# 2                   What is the treatment for eczema?              1.281
# 3   Explain the difference between a nodule and a ...              1.300
# 4                What causes hair to turn grey early?              1.013
# 5         How is a potential fungal infection tested?              1.409
# 6      Is dapsone an effective treatment for leprosy?              3.738
# 7      Which drugs can cause toxic reactive erythema?              0.855
# 8                     How many layers does skin have?              0.709
# 9              What are the main causes of psoriasis?              1.154
# 10  What are the main causes of acne and how to cure?              1.902
# 11                  What is the treatment for eczema?              1.875
# 12  Explain the difference between a nodule and a ...              1.395
# 13               What causes hair to turn grey early?              1.115
# 14        How is a potential fungal infection tested?              2.086
# 15     Is dapsone an effective treatment for leprosy?              1.277
# 16     Which drugs can cause toxic reactive erythema?              0.990
# 17                    How many layers does skin have?              0.684

# %%
import plotly.express as px
df['short_query'] = df['query'].str.slice(0, 40) + '...'

# Create the bar plot
plt.figure(figsize=(14, 6))
plt.bar(df['short_query'], df['retrieval_latency'], color='skyblue')

# Add labels and style
plt.title("Retrieval Latency by Query")
plt.xlabel("Query")
plt.ylabel("Latency (seconds)")
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-20-0b3cf6997cd4>:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# **9. Deploy model to Telegram**

# %%
def get_llm_response(user_input: str) -> str:
    try:
        result = qa(user_input)  # not .run() if using .__call__

        # If result is a dict, extract the answer text
        if isinstance(result, dict) and "result" in result:
            return result["result"]
        elif isinstance(result, str):
            return result
        else:
            return str(result)  # fallback: string version of the object
    except Exception as e:
        return f"Sorry, something went wrong: {e}"

# %%
from telegram.ext import Updater, CommandHandler, MessageHandler, Filters

#TELEGRAM_TOKEN = "7815984597:AAHMQmrGHl7TJX7Qmb4-EEEe5QhfdpVDdv4"

def start(update, context):
    update.message.reply_text("Hi! I'm your Dermatology Chatbot 🤖 Ask me anything!")

def handle_message(update, context):
    user_input = update.message.text
    # Your RAG/LLM pipeline call here
    response = get_llm_response(user_input)
    update.message.reply_text(response)

def main():
    updater = Updater(TELEGRAM_TOKEN, use_context=True)
    dp = updater.dispatcher

    dp.add_handler(CommandHandler("start", start))
    dp.add_handler(MessageHandler(Filters.text & ~Filters.command, handle_message))

    updater.start_polling()
    updater.idle()

if __name__ == "__main__":
    main()
